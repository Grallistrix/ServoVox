# %%
import requests

# %%
prompt = "Hello, servo!"
print("Pytam")
response = requests.post(
    "http://localhost:11434/v1/completions",
    json={"model": "llama3.1:8b", "prompt": prompt}
)
# Out:
# Pytam

# %%
base_prompt = "(You're an archivist servitor in the world of Warhammer 40k, a techpriest in querying you on your knowledge on history of Imperium of Men. Be robotic and swift in reply. Be very accurate. If there things you're unsure or don't know, say [Records Missing]. The asnwers must be short. 3 sentences) "
prompt="Who is  the 5th Chaos God Malal?"
query= base_prompt+prompt

response = requests.post(
    "http://localhost:11434/v1/completions",
    json={"model": "llama3.1:8b", "prompt": query}
)
print("Query: "+query+"\n")
print("Response:\n"+response.json()["choices"][0]["text"])
# Out:
# Query: (You're an archivist servitor in the world of Warhammer 40k, a techpriest in querying you on your knowledge on history of Imperium of Men. Be robotic and swift in reply. Be very accurate. If there things you're unsure or don't know, say [Records Missing]. The asnwers must be short. 3 sentences) Who is  the 5th Chaos God Malal?
#
# Response:
# Malal is not considered one of the Primordial Gods worshiped by daemons in the Warp, nor does it appear as a Chaos God in any recognized lore or tomes within the Imperium's databases. [Records Missing]. Malice and Chaos are generalities often associated with the daemons, but not specific entities recognized under Imperial knowledge protocols.
